# %% [markdown]
# # TP Ecosistema
# ---

# %% [markdown]
# ##### Crear repositorio en GitHub / GitLab

# %% [markdown]
# ##### Mapa Conceptual usando Mermaid

# %%
```mermaid
graph TD
    A[Ecosistema Backend] --> B(Lenguajes)
    A --> C(Frameworks)
    B --> JS[JavaScript]
    B --> PY[Python]
    B --> JV[Java]
    C --> EX[Express]
    C --> DJ[Django]
    C --> SB[Spring Boot]
    EX --- JS
    DJ --- PY
    SB --- JV

# %% [markdown]
# ##### Completar cuadro comparativo entre diferentes frameworks web backend

# %% [markdown]
# |                       || | Flask (Python) | Django (Python) | FastAPI (Python) | Express (Node.js) | Spring Boot (Java) | Laravel (PHP) |
# | :--- | :--- | :--- | :--- | :--- | :--- | :--- |
# | **Desarrollador** | Armin Ronacher | A. Holovaty / S. Willison | Sebastián Ramírez | TJ Holowaychuk | Pivotal (VMware) | Taylor Otwell |
# | **Curva aprendizaje** | Muy Baja | Media | Baja | Media | Alta | Media |
# | **Rendimiento** | Medio | Medio | Muy Alto | Muy Alto | Alto | Medio |
# | **Ideal para...** | Microservicios | Apps Complejas | APIs Rápidas | Tiempo Real | Enterprise | Web tradicional |
# | **Popularidad** | Alta | Muy Alta | En Crecimiento | Muy Alta | Muy Alta | Alta |
# | **Pasos HolaMundo** | `app.run()` | `runserver` | `uvicorn main:app` | `node app.js` | `mvn spring-boot:run` | `php artisan serve` |
